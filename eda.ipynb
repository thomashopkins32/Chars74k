# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
labels = pd.read_csv('trainLabels.csv', index_col='ID')

# %%
plt.figure(figsize=(20, 10))
plt.title('Label Counts')
labels.Class.value_counts().plot.bar()
# Out:
# <AxesSubplot:title={'center':'Label Counts'}>

# %%
image = Image.open('trainResized/1.Bmp')
print(labels.loc[1].Class)
image
# Out:
# n
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=20x20 at 0x2C9508B1C70>

# %%
print(len(labels.Class.value_counts()))
# Out:
# 62
