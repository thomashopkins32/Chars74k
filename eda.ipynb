# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import dataset as data

# %%
labels = pd.read_csv('trainLabels.csv', index_col='ID')

# %%
plt.figure(figsize=(20, 10))
plt.title('Label Counts')
labels.Class.value_counts().plot.bar()
# Out:
# <Axes: title={'center': 'Label Counts'}>

# %%
import torchvision as tv

transform = tv.transforms.RandomAutocontrast(0.5)
image = transform(Image.open('trainResized/1.Bmp').convert('RGB'))
print(labels.loc[1].Class)
image
# Out:
# n
# <PIL.Image.Image image mode=RGB size=20x20>

# %%
print(len(labels.Class.value_counts()))
# Out:
# 62

# %%
train = data.Chars74k(test=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train = data.Chars74k(test=False)
#
# File c:\Users\thoma\Documents\GitHub\Chars74k\dataset.py:17, in Chars74k.__init__(self, test)
#      15     self.path = 'trainResized/'
#      16 self.labels = pd.read_csv('trainLabels.csv', index_col='ID')
# ---> 17 self.transform = tv.transforms.Compose(
#      18     tv.transforms.RandomAutocontrast(),
#      19     tv.transforms.ToTensor(),
#      20 )
#      21 self.idx_to_char = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789'
#      22 self.char_to_idx = {c: i for i, c in enumerate(self.idx_to_char)}
#
# TypeError: Compose.__init__() takes 2 positional arguments but 3 were given

# %%
item = train[1]
# Out:
# torch.Size([3, 20, 20])

# %%
item.dtype
# Out:
# torch.float32

# %%
item
# Out:
# tensor([[[0.4235, 0.4196, 0.4235,  ..., 0.4118, 0.4353, 0.4353],
#          [0.4314, 0.4275, 0.4235,  ..., 0.4471, 0.4275, 0.4235],
#          [0.4353, 0.4314, 0.4196,  ..., 0.4510, 0.4353, 0.4235],
#          ...,
#          [0.4314, 0.4275, 0.4275,  ..., 0.4275, 0.4078, 0.4118],
#          [0.4235, 0.4549, 0.4510,  ..., 0.4353, 0.4196, 0.4235],
#          [0.4314, 0.4275, 0.4235,  ..., 0.4275, 0.4157, 0.4039]],
#
#         [[0.4784, 0.4784, 0.4784,  ..., 0.4745, 0.4706, 0.4667],
#          [0.4706, 0.4706, 0.4745,  ..., 0.4745, 0.4784, 0.4784],
#          [0.4745, 0.4784, 0.4745,  ..., 0.4667, 0.4706, 0.4667],
#          ...,
#          [0.4941, 0.4824, 0.4824,  ..., 0.4588, 0.4588, 0.4627],
#          [0.4627, 0.4902, 0.4941,  ..., 0.4627, 0.4627, 0.4667],
#          [0.4667, 0.4627, 0.4588,  ..., 0.4667, 0.4667, 0.4706]],
#
#         [[0.4902, 0.4980, 0.5020,  ..., 0.5059, 0.4941, 0.4784],
#          [0.4863, 0.4980, 0.5098,  ..., 0.5020, 0.4941, 0.4902],
# ...
